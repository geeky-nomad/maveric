# %%
import re
import nltk
import pandas as pd
# load the csv
df = pd.read_csv('update_fashion.csv')
df.head(2)
# Out:
#   BrandName                                            Details  \
# 0      life  solid cotton blend collar neck womens a-line d...
# 1      only    polyester peter pan collar womens blouson dress
#
#                                      Sizes     MRP  SellPrice  Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  1699.0      849.0      50.0
# 1                         Size:34,36,38,40  3499.0     2449.0      30.0
#
#         Category  Colour
# 0   a-line dress  indigo
# 1  blouson dress  yellow

# %%
# Tokenization -> Details
def tokenization(text):
    tokens = text.split()
    return tokens

stopwords = nltk.corpus.stopwords.words('english')

def remove_stopword(tokenize_item):
    item = [text for text in tokenize_item if text not in stopwords]
    return item

# Apply both functions in a single line
df['Tokenized_Details'] = df['Details'].apply(lambda x: remove_stopword(tokenization(x)))

# now finally saving it in new csv
t_shirts_df = df[df['Category'] == 't-shirts']
t_shirts_df
# df[:10]
# Out:
#       BrandName                                          Details  \
# 1473  vero moda        printed modal round neck womens  t-shirts
# 1544  vero moda      textured cotton round neck womens  t-shirts
# 2289  vero moda      textured cotton round neck womens  t-shirts
# 3339  vero moda       printed cotton round neck womens  t-shirts
# 4512  vero moda       printed cotton round neck womens  t-shirts
# 4564  vero moda  printed cotton blend round neck womens t-shirts
# 5003  vero moda             solid cotton v neck womens  t-shirts
# 5120  vero moda       printed cotton round neck womens  t-shirts
# 5166  vero moda       printed cotton round neck womens  t-shirts
# 5415  vero moda       printed cotton round neck womens  t-shirts
# 6126  vero moda    printed polyester round neck womens  t-shirts
# 6271  vero moda       printed cotton round neck womens  t-shirts
# 6279  vero moda        printed modal round neck womens  t-shirts
# 6375  vero moda      textured cotton round neck womens  t-shirts
# 6829  vero moda   embellished cotton round neck womens  t-shirts
# 7111  vero moda       stripes cotton round neck womens  t-shirts
# 7124  vero moda       printed cotton round neck womens  t-shirts
# 7275  vero moda           printed cotton v neck womens  t-shirts
# 7370  vero moda        printed modal round neck womens  t-shirts
# 7426  vero moda       stripes cotton round neck womens  t-shirts
# 7725  vero moda    printed polyester round neck womens  t-shirts
# 7960  vero moda       printed cotton round neck womens  t-shirts
# 7961  vero moda       printed cotton round neck womens  t-shirts
#
#                                         Sizes     MRP  SellPrice  Discount  \
# 1473  Size:Large,Medium,Small,X-Large,X-Small  1299.0      909.0      30.0
# 1544  Size:Large,Medium,Small,X-Large,X-Small  1899.0     1329.0      30.0
# 2289  Size:Large,Medium,Small,X-Large,X-Small  1899.0     1329.0      30.0
# 3339  Size:Large,Medium,Small,X-Large,X-Small   999.0      599.0      40.0
# 4512  Size:Large,Medium,Small,X-Large,X-Small  1799.0     1259.0      30.0
# 4564  Size:Large,Medium,Small,X-Large,X-Small  2499.0     1249.0      50.0
# 5003  Size:Large,Medium,Small,X-Large,X-Small  1299.0      779.0      40.0
# 5120  Size:Large,Medium,Small,X-Large,X-Small  1799.0     1259.0      30.0
# 5166  Size:Large,Medium,Small,X-Large,X-Small  1299.0      909.0      30.0
# 5415  Size:Large,Medium,Small,X-Large,X-Small   999.0      699.0      30.0
# 6126  Size:Large,Medium,Small,X-Large,X-Small  1299.0      779.0      40.0
# 6271  Size:Large,Medium,Small,X-Large,X-Small  1499.0     1049.0      30.0
# 6279  Size:Large,Medium,Small,X-Large,X-Small   999.0      699.0      30.0
# 6375  Size:Large,Medium,Small,X-Large,X-Small   999.0      699.0      30.0
# 6829  Size:Large,Medium,Small,X-Large,X-Small  1499.0     1049.0      30.0
# 7111  Size:Large,Medium,Small,X-Large,X-Small  1599.0     1119.0      30.0
# 7124  Size:Large,Medium,Small,X-Large,X-Small  2299.0     1379.0      40.0
# 7275  Size:Large,Medium,Small,X-Large,X-Small  1499.0     1049.0      30.0
# 7370  Size:Large,Medium,Small,X-Large,X-Small   999.0      699.0      30.0
# 7426  Size:Large,Medium,Small,X-Large,X-Small  1299.0      779.0      40.0
# 7725  Size:Large,Medium,Small,X-Large,X-Small  1299.0      779.0      40.0
# 7960  Size:Large,Medium,Small,X-Large,X-Small  2299.0     1379.0      40.0
# 7961  Size:Large,Medium,Small,X-Large,X-Small  1299.0      909.0      30.0
#
#       Category    Colour                                  Tokenized_Details
# 1473  t-shirts     white    [printed, modal, round, neck, womens, t-shirts]
# 1544  t-shirts    purple  [textured, cotton, round, neck, womens, t-shirts]
# 2289  t-shirts    yellow  [textured, cotton, round, neck, womens, t-shirts]
# 3339  t-shirts      pink   [printed, cotton, round, neck, womens, t-shirts]
# 4512  t-shirts    orange   [printed, cotton, round, neck, womens, t-shirts]
# 4564  t-shirts    orange  [printed, cotton, blend, round, neck, womens, ...
# 5003  t-shirts     green         [solid, cotton, v, neck, womens, t-shirts]
# 5120  t-shirts      pink   [printed, cotton, round, neck, womens, t-shirts]
# 5166  t-shirts   fuschia   [printed, cotton, round, neck, womens, t-shirts]
# 5415  t-shirts     white   [printed, cotton, round, neck, womens, t-shirts]
# 6126  t-shirts    yellow  [printed, polyester, round, neck, womens, t-sh...
# 6271  t-shirts     white   [printed, cotton, round, neck, womens, t-shirts]
# 6279  t-shirts     white    [printed, modal, round, neck, womens, t-shirts]
# 6375  t-shirts      pink  [textured, cotton, round, neck, womens, t-shirts]
# 6829  t-shirts     white  [embellished, cotton, round, neck, womens, t-s...
# 7111  t-shirts      blue   [stripes, cotton, round, neck, womens, t-shirts]
# 7124  t-shirts      pink   [printed, cotton, round, neck, womens, t-shirts]
# 7275  t-shirts       red       [printed, cotton, v, neck, womens, t-shirts]
# 7370  t-shirts      blue    [printed, modal, round, neck, womens, t-shirts]
# 7426  t-shirts      pink   [stripes, cotton, round, neck, womens, t-shirts]
# 7725  t-shirts  lavender  [printed, polyester, round, neck, womens, t-sh...
# 7960  t-shirts     white   [printed, cotton, round, neck, womens, t-shirts]
# 7961  t-shirts     white   [printed, cotton, round, neck, womens, t-shirts]
