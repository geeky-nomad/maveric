# %%
import pandas as pd
import re
# Set the maximum column width to ensure complete values are shown
pd.set_option('display.max_colwidth', None)

# Set the maximum column width to ensure complete values are shown
pd.set_option('display.max_rows', None)

# loading the dataset for hiketron -> for all categories
all_products_df = pd.read_csv('FashionDataset_New.csv')
all_products_df['Colour'].drop_duplicates().to_list()
# Out:
# ['indigo',
#  'yellow',
#  'off white',
#  'black',
#  'stone',
#  'light blue',
#  'white',
#  'blush',
#  'navy',
#  'pink',
#  'orange',
#  'blue',
#  'maroon',
#  'mid stone',
#  'olive',
#  'ecru',
#  'green',
#  'pink mix',
#  'dark brown',
#  'sage',
#  'mustard',
#  'natural',
#  'grey',
#  'blue denim',
#  'red',
#  'baby pink',
#  'brown',
#  'dk indigo',
#  'lilac',
#  'aubergine',
#  'tan',
#  'pista green',
#  'dark blue',
#  'powder blue',
#  'misty lilac',
#  'wine',
#  'multi',
#  'bottle green',
#  'peach',
#  'dusty pink',
#  'charcoal',
#  'mauve',
#  'lavender',
#  'cream',
#  'mint',
#  'purple',
#  'royal blue',
#  'rose',
#  'sky blue',
#  'teal',
#  'ice',
#  'gold',
#  'lime green',
#  'ivory',
#  'black mix',
#  'ice blue',
#  'old rose',
#  'print',
#  'fuschia',
#  'ocean',
#  'chocolate',
#  'grey melange',
#  'dark grey',
#  'magenta',
#  'burgundy',
#  'aqua',
#  'denimex',
#  'anthra melange',
#  'apple green',
#  'walnut',
#  'dark green',
#  'stonewash blue',
#  'rust',
#  'khaki',
#  'ltgrey',
#  'red mix',
#  'mid blue',
#  'coral',
#  'air force',
#  'sand',
#  'midstone',
#  'blue mix light',
#  'berry',
#  'anthra',
#  'beige',
#  'honey',
#  'brick',
#  'cloud',
#  'biscuit',
#  'cobalt',
#  'sea blue',
#  'porcelain',
#  'checks',
#  'lemon',
#  '106_multi',
#  'deep navy',
#  'denim indigo dark',
#  'mineral',
#  'pale peach',
#  'plum',
#  'linen',
#  'pale yellow',
#  nan,
#  'emerald',
#  'butter',
#  'midnight blue',
#  'turquoise',
#  'major brown',
#  'fuchsia',
#  'double black',
#  'moss green',
#  'dark pink',
#  'carbon',
#  'nude',
#  'rinse',
#  'burnt orange',
#  'light olive',
#  'sea green',
#  'mixed darks',
#  'rosewood',
#  'peacock',
#  'tint',
#  'camel',
#  'glaze',
#  'buff',
#  'true navy',
#  'grey pink',
#  'denim',
#  'rose gold',
#  'light mauve',
#  'gray',
#  'ginger snap',
#  'ribbon red',
#  'bronze',
#  'streaky brown',
#  'brown mix',
#  'bleach',
#  'denim enzyme',
#  'mood indigo',
#  'ink blue',
#  'twill mud',
#  'salmon',
#  'flash',
#  'teal_green',
#  'ether',
#  'mid used',
#  'shocking pink',
#  'light brown',
#  'champagne',
#  'bubblegum',
#  'capri blue',
#  'navy marl',
#  'sunset',
#  'marine green',
#  'legend blue',
#  'silver grey',
#  'aviator',
#  'leaf green',
#  'retro navy',
#  'candy',
#  'cherry',
#  'mastic white',
#  'default color 1',
#  'mullet',
#  'herb green',
#  'mango',
#  'royal',
#  'pack of 1',
#  'canal',
#  'silver',
#  'blue melange',
#  'violet',
#  'denim indigo light',
#  'island blue',
#  'green mix',
#  'birch',
#  'ochre',
#  'shrimp',
#  'ultramarine',
#  'sugar',
#  'amber',
#  'taupe',
#  'denim regular',
#  'electric',
#  'flamingo',
#  'carmine',
#  'coffee',
#  'off_white',
#  'sky',
#  'merc black',
#  'blasted navy',
#  'spice',
#  'acid green',
#  'dark olive',
#  'graphite',
#  'chalk pink',
#  'crystal',
#  'orange mix',
#  'indiaink',
#  'petal',
#  'light vintage',
#  'super stone dustered',
#  'dusty rose',
#  'fawn',
#  'dark stonewash',
#  'fluid_olive',
#  'ink',
#  'dave grey',
#  'shell',
#  'carrot',
#  'cactus',
#  'cider',
#  'black rinse',
#  'new grey',
#  'buttercup',
#  'weft_blue',
#  'dark streak',
#  'cool ice',
#  'olive bleached',
#  'black grey',
#  'fir green',
#  'mastic thread dark stone',
#  'dark slate',
#  'grey cast',
#  'cane',
#  'cadet',
#  'blasted olive tone',
#  'jade',
#  'purple mix',
#  'maple',
#  'abraded stone',
#  'moore plum',
#  'mixed pastels',
#  'imperial yellow',
#  'denim black',
#  'smoke',
#  'steel',
#  'thistle',
#  'snow',
#  'mouse',
#  'soft grey',
#  'dusty peach',
#  'onion_pink',
#  'lt tan',
#  'vintage blue',
#  'terracotta',
#  'bluesteel',
#  'misty blue',
#  'seagreen',
#  'tomato',
#  'silver cloud',
#  'marine',
#  'light orange',
#  'lime',
#  'copper',
#  'pale pink',
#  'raspberry',
#  'pistachio',
#  'midnight']
